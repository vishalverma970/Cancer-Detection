# %% [markdown]
# # Step - 1 : Brief description of the problem and data

# %% [markdown]
# #### Objective of this problem is to identify metastatic cancer in small image patches taken from larger digital pathology scans.
#
# Submissions are evaluated on area under the ROC curve between the predicted probability and the observed target.

# %% [markdown]
# #### Data is divided into train and test :
# Train data contains 220025 images and test data contains 57458 images

# %% [markdown]
# Data is modified version of the PatchCamelyon (PCam) benchmark dataset. The original PCam dataset contains duplicate images. however, the version presented on Kaggle does not contain duplicates.

# %% [markdown]
# This is binary classification problem, Our target variable has a distribution of 40.5% as 1 (has cancer tissues) and 59.5% as 0 (has no cancer tissues)

# %% [markdown]
# objective is to train model on the image in train folder and then label the images in test folder, whether that image contains cancer tissue or not

# %% [markdown]
# ## Loading Data and processing images

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kaggle
import json
import zipfile
import os
from tensorflow.keras.preprocessing import image
from PIL import Image
import cv2
from tqdm import tqdm_notebook,trange
from tqdm.notebook import tqdm
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization, Activation
from keras.layers import Conv2D, MaxPool2D
from keras.layers import Conv2D, AveragePooling2D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from keras.utils import np_utils
import kaggle
from sklearn.metrics import roc_auc_score
from sklearn import metrics

# %%
basedir = '/Users/vishalverma/Vishal/git/Data/Cancer detection/Data/histopathologic-cancer-detection/'

# %%
sample_sub = pd.read_csv(basedir + 'sample_submission.csv')
train_df1 = pd.read_csv(basedir + 'train_labels.csv')

# %%
print('Number of training case : {}'.format(train_df1.shape[0]))
print('Number of test case : {}'.format(len(os.listdir(basedir + 'test/'))))
# Out:
# Number of training case : 220025
# Number of test case : 57458

# %% [markdown]
# #### Processing images to matrix

# %%
def load_data(path,N,df):
    """ This functions loads N images using the data df
    """
    # allocate a numpy array for the images (N, 96x96px, 3 channels, values 0 - 255)
    X = np.zeros([N,96,96,3],dtype=np.uint8) 
    #convert the labels to a numpy array too
    y = np.squeeze(df.label.values)[0:N]
    #read images one by one, tdqm notebook displays a progress bar
    for i, row in tqdm(df.iterrows(), total=N):
        if i == N:
            break
        X[i] = cv2.imread(path + row['id'] + '.tif')
          
    return X,y

# %%
def visualize_img1(path1,img_list1,df1,plt_matrix):
    fig,axes = plt.subplots(plt_matrix[0],plt_matrix[1],figsize = (20,5))
    
    for indx,img in enumerate(img_list1):
        #print(indx//plt_matrix[1])
        axes[indx//plt_matrix[1], indx - (indx//plt_matrix[1])*(plt_matrix[1])].set_xticks([])
        axes[indx//plt_matrix[1], indx - (indx//plt_matrix[1])*(plt_matrix[1])].set_yticks([])
        axes[indx//plt_matrix[1], indx - (indx//plt_matrix[1])*(plt_matrix[1])].imshow(Image.open(path1 + img))
        axes[indx//plt_matrix[1], indx - (indx//plt_matrix[1])*(plt_matrix[1])].title.set_text('lable = {}'.format(df1[df1.id == img.split('.')[0]].label.values[0]))

# %%
def rgb_plt1(axes,data1,bins,title,ylabel,xlabel):
    axes.hist(data1.flatten(),bins=bins,density = True)
    axes.set_title(title)
    axes.set_ylabel(ylabel,rotation='horizontal',labelpad=35,fontsize=12)
    axes.set_xlabel("Pixel value")
    
    return fig.tight_layout()

# %%
def visual_results(model_1,test_df_x,test_df_y):
    fig,axes = plt.subplots(1,3,figsize = (20,5))
    
    axes[0].plot(model_1.history["loss"], label='Training loss')
    axes[0].plot(model_1.history["val_loss"], label='Validation loss')
    axes[0].set_xlabel("Epochs")
    axes[0].set_ylabel("Loss")
    axes[0].legend(frameon=False)
    
    axes[1].plot(model_1.history["accuracy"], label='Training accuracy')
    axes[1].plot(model_1.history["val_accuracy"], label='Validation accuracy')
    axes[1].set_xlabel("Epochs")
    axes[1].set_ylabel("Loss")
    axes[1].legend(frameon=False)
    
    
    y_pred_keras = model.predict_generator(test_df_x, verbose=1)
    score = model.evaluate(test_x, test_y, verbose=0)
    
    
    print(f'Test loss: {score[0]} / Test accuracy: {score[1]} / Test Roc : {roc_auc_score(test_df_y,y_pred_keras)}')
    
    
    fpr, tpr, _ = metrics.roc_curve(test_y,  y_pred_keras)
    
    axes[2].plot(fpr,tpr)
    axes[2].set_ylabel("True Positive Rate")
    axes[2].set_xlabel("False Positive Rate")

# %% [markdown]
# # Step - 2 : Exploratory data analysis

# %%
val1 = train_df1.label.value_counts(normalize=True).values
labels1 = train_df1.label.value_counts(normalize=True).index

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(val1, labels=labels1, autopct='%.1f%%')
ax.set_title('Target distribution')
plt.tight_layout()

# %% [markdown]
# ### Images details

# %%
image1 = image.load_img(basedir + 'train/' + train_df1.id[0] + '.tif')

# convert image to. a matrix
img_ts = image.img_to_array(image1)
print(img_ts.shape)
# Out:
# (96, 96, 3)

# %% [markdown]
# Each image size 96X96 pixel with 3 channel of RGB

# %%
img_lst = os.listdir(basedir + 'train/')

# %%
select_norm = np.random.choice(img_lst, 10, replace = False)

# %% [markdown]
# ### Visualizing 10 images randomly

# %%
visualize_img1(basedir + 'train/',select_norm,train_df1,[2,5])

# %% [markdown]
# ### Visualizing 10 image with label = 1

# %%
select_norm1 = np.random.choice(train_df1.id[train_df1.label == 1].tolist(),10,replace=False)
select_norm1 = [chr1 + '.tif' for chr1 in select_norm1]

# %%
visualize_img1(basedir + 'train/',select_norm1,train_df1,[2,5])

# %% [markdown]
# ### Visualizing 10 images with label = 0

# %%
select_norm3 = np.random.choice(train_df1.id[train_df1.label == 0].tolist(),10,replace = False)
select_norm3 = [chr1 + '.tif' for chr1 in select_norm3]

# %%
visualize_img1(basedir + 'train/',select_norm3,train_df1,[2,5])

# %%
N=25000
X,y = load_data(basedir + 'train/',N=N,df=train_df1)
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]

# %%
positive_cases = X[y == 1]
negative_cases = X[y == 0]

# %%
positive_cases.shape
# Out:
# (10064, 96, 96, 3)

# %% [markdown]
# comparing pixel value for both negative vs positive

# %%
nr_of_bins = 256 #each possible pixel value will get a bin in the following histograms
fig,axs = plt.subplots(4,2,sharey=True,figsize=(8,8),dpi=80)

rgb_plt1(axs[0,0],positive_cases[:,:,:,0],nr_of_bins,
         'Positive Samples (N = {})'.format(str(positive_cases.shape[0])),'Red','Pixel value')

rgb_plt1(axs[0,1],negative_cases[:,:,:,0],nr_of_bins,
         'Negative Samples (N = {})'.format(str(negative_cases.shape[0])),'Red','Pixel value')

rgb_plt1(axs[1,0],positive_cases[:,:,:,1],nr_of_bins,
         'Positive Samples (N = {})'.format(str(positive_cases.shape[0])),'Green','Pixel value')

rgb_plt1(axs[1,1],negative_cases[:,:,:,1],nr_of_bins,
         'Negative Samples (N = {})'.format(str(negative_cases.shape[0])),'Green','Pixel value')
                       
rgb_plt1(axs[2,0],positive_cases[:,:,:,2],nr_of_bins,
         'Positive Samples (N = {})'.format(str(positive_cases.shape[0])),'Blue','Pixel value')

rgb_plt1(axs[2,1],negative_cases[:,:,:,2],nr_of_bins,
         'Negative Samples (N = {})'.format(str(negative_cases.shape[0])),'Blue','Pixel value')

rgb_plt1(axs[3,0],positive_cases,nr_of_bins,
         'Positive Samples (N = {})'.format(str(positive_cases.shape[0])),'RGB','Pixel value')

rgb_plt1(axs[3,1],negative_cases,nr_of_bins,
         'Negative Samples (N = {})'.format(str(negative_cases.shape[0])),'RGB','Pixel value')

# %% [markdown]
# High pixel value means brighter colour and low pixel value means darker colour.

# %% [markdown]
# We can see difference in the distribution of positive vs negative cases.
#
# * In negative case we can see high pixel value compare to positive case.
# * Comparatively green colour have low pixel value in positive case. Other channels are skewed toward 255 we are green channel shows normal distribution with high frequency at 100 pixel value.

# %% [markdown]
# ### Mean pixel comparision

# %%
nr_of_bins = 50 
fig,axs = plt.subplots(1,2,sharey=True,figsize=(8,5),dpi=80)

rgb_plt1(axs[0],np.mean(positive_cases,axis = (1,2,3)),nr_of_bins,
         'Mean pixel : Positive'.format(str(positive_cases.shape[0])),'Frequency','Pixel value')

rgb_plt1(axs[1],np.mean(negative_cases,axis = (1,2,3)),nr_of_bins,
         'Mean pixel : Negative'.format(str(positive_cases.shape[0])),'Frequency','Pixel value')

# %% [markdown]
# comparing mean distribution we can see a significant different between both positive and negative case.
# frequency is high at 150 pixel in positive cases whereas in negative case we see a drop in frequency between 150 and 200 range

# %% [markdown]
# #### Splitting data into test, train and validation set

# %% [markdown]
# To begin with we are building model only on 20000 images, we will first divide data into train,validation and test set

# %%
N=25000
X,y = load_data(basedir + 'train/',N=N,df=train_df1)
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, train_size = 0.8, random_state = 42)

val_size = int(0.5*len(test_x))

val_x = test_x[:val_size]
val_y = test_y[:val_size]
test_x = test_x[val_size:]
test_y = test_y[val_size:]

# %% [markdown]
# # Step - 3 DModel Architecture

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# In base line model we start with 3 convolution layer  with following parameter:
# * Filter size = 3
# * Filter in first convolution layer 32
# * Filter in second convolution layer 64
# * Filter in third convolution layer 128
# * Pooling for parameter reduction of size 2
# * Number of epoch 15
# * batch size 100

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 200

# %%
#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, activation='relu', input_shape=(96, 96, 3)))
model.add(MaxPool2D(pool_size))
model.add(Conv2D(second_filters, kernel_size, activation='relu'))
model.add(MaxPool2D(pool_size))
model.add(Conv2D(third_filters, kernel_size, activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Metal device set to: Apple M1
# 2022-05-25 13:07:12.065862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-25 13:07:12.066086: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
# 2022-05-25 13:07:12.511037: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-25 13:07:12.760296: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 100/100 [==============================] - ETA: 0s - loss: 25.6887 - accuracy: 0.5874
# 2022-05-25 13:07:33.656430: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.62442, saving model to weights.hdf5
# 100/100 [==============================] - 22s 215ms/step - loss: 25.6887 - accuracy: 0.5874 - val_loss: 0.6244 - val_accuracy: 0.6760
# Epoch 2/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6141 - accuracy: 0.6218
# Epoch 2: val_loss improved from 0.62442 to 0.61467, saving model to weights.hdf5
# 100/100 [==============================] - 21s 213ms/step - loss: 0.6141 - accuracy: 0.6218 - val_loss: 0.6147 - val_accuracy: 0.6108
# Epoch 3/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6967 - accuracy: 0.5995
# Epoch 3: val_loss did not improve from 0.61467
# 100/100 [==============================] - 21s 211ms/step - loss: 0.6967 - accuracy: 0.5995 - val_loss: 0.6804 - val_accuracy: 0.6036
# Epoch 4/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6836 - accuracy: 0.5967
# Epoch 4: val_loss did not improve from 0.61467
# 100/100 [==============================] - 21s 212ms/step - loss: 0.6836 - accuracy: 0.5967 - val_loss: 0.6728 - val_accuracy: 0.6040
# Epoch 5/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6737 - accuracy: 0.5971
# Epoch 5: val_loss did not improve from 0.61467
# 100/100 [==============================] - 21s 213ms/step - loss: 0.6737 - accuracy: 0.5971 - val_loss: 0.6716 - val_accuracy: 0.6044
# Epoch 6/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6714 - accuracy: 0.5972
# Epoch 6: val_loss did not improve from 0.61467
# 100/100 [==============================] - 21s 212ms/step - loss: 0.6714 - accuracy: 0.5972 - val_loss: 0.6757 - val_accuracy: 0.6040
# Epoch 7/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.5988
# Epoch 7: val_loss did not improve from 0.61467
# 100/100 [==============================] - 21s 212ms/step - loss: 0.6680 - accuracy: 0.5988 - val_loss: 0.6735 - val_accuracy: 0.6044

# %%
visual_results(base_model,test_x,test_y)
# Out:
#  4/79 [>.............................] - ETA: 1s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 13:09:42.281014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 2s 23ms/step
# Test loss: 0.672238826751709 / Test accuracy: 0.5964000225067139 / Test Roc : 0.5108770528627764

# %% [markdown]
# In this model we are getting roc score of 0.51 which is quit low

# %% [markdown]
# ### Model 2

# %% [markdown]
# Adding batch normalization to see if we can improve our model

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 100

# %%
#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))


model.add(Conv2D(second_filters, kernel_size))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))

model.add(Conv2D(third_filters, kernel_size))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
# 2022-05-25 13:18:22.279391: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 200/200 [==============================] - ETA: 0s - loss: 0.7220 - accuracy: 0.7851
# 2022-05-25 13:18:50.806875: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss did not improve from 0.61467
# 200/200 [==============================] - 30s 143ms/step - loss: 0.7220 - accuracy: 0.7851 - val_loss: 1.1304 - val_accuracy: 0.5552
# Epoch 2/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3977 - accuracy: 0.8281
# Epoch 2: val_loss improved from 0.61467 to 0.49332, saving model to weights.hdf5
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3977 - accuracy: 0.8281 - val_loss: 0.4933 - val_accuracy: 0.7820
# Epoch 3/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8358
# Epoch 3: val_loss did not improve from 0.49332
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3804 - accuracy: 0.8358 - val_loss: 0.5259 - val_accuracy: 0.7980
# Epoch 4/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.8467
# Epoch 4: val_loss did not improve from 0.49332
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3615 - accuracy: 0.8467 - val_loss: 0.4948 - val_accuracy: 0.7880
# Epoch 5/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8491
# Epoch 5: val_loss improved from 0.49332 to 0.38664, saving model to weights.hdf5
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3536 - accuracy: 0.8491 - val_loss: 0.3866 - val_accuracy: 0.8336
# Epoch 6/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8586
# Epoch 6: val_loss did not improve from 0.38664
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3328 - accuracy: 0.8586 - val_loss: 0.4217 - val_accuracy: 0.8144
# Epoch 7/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3261 - accuracy: 0.8607
# Epoch 7: val_loss did not improve from 0.38664
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3261 - accuracy: 0.8607 - val_loss: 1.7007 - val_accuracy: 0.6680
# Epoch 8/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3036 - accuracy: 0.8712
# Epoch 8: val_loss did not improve from 0.38664
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3036 - accuracy: 0.8712 - val_loss: 0.4182 - val_accuracy: 0.8184
# Epoch 9/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.8773
# Epoch 9: val_loss did not improve from 0.38664
# 200/200 [==============================] - 28s 139ms/step - loss: 0.2973 - accuracy: 0.8773 - val_loss: 0.9334 - val_accuracy: 0.7196
# Epoch 10/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8818
# Epoch 10: val_loss improved from 0.38664 to 0.36413, saving model to weights.hdf5
# 200/200 [==============================] - 28s 140ms/step - loss: 0.2856 - accuracy: 0.8818 - val_loss: 0.3641 - val_accuracy: 0.8440
# Epoch 11/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8855
# Epoch 11: val_loss did not improve from 0.36413
# 200/200 [==============================] - 28s 139ms/step - loss: 0.2716 - accuracy: 0.8855 - val_loss: 0.4327 - val_accuracy: 0.8408
# Epoch 12/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.8933
# Epoch 12: val_loss did not improve from 0.36413
# 200/200 [==============================] - 28s 139ms/step - loss: 0.2601 - accuracy: 0.8933 - val_loss: 1.8813 - val_accuracy: 0.7248
# Epoch 13/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9062
# Epoch 13: val_loss did not improve from 0.36413
# 200/200 [==============================] - 28s 140ms/step - loss: 0.2330 - accuracy: 0.9062 - val_loss: 0.5375 - val_accuracy: 0.7792
# Epoch 14/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9143
# Epoch 14: val_loss did not improve from 0.36413
# 200/200 [==============================] - 28s 140ms/step - loss: 0.2118 - accuracy: 0.9143 - val_loss: 0.5625 - val_accuracy: 0.7832
# Epoch 15/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9190
# Epoch 15: val_loss did not improve from 0.36413
# 200/200 [==============================] - 28s 140ms/step - loss: 0.2025 - accuracy: 0.9190 - val_loss: 1.0224 - val_accuracy: 0.7500

# %%
visual_results(base_model,test_x,test_y)
# Out:
#  2/79 [..............................] - ETA: 6s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 13:25:21.327816: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 17ms/step
# 2022-05-25 13:25:22.788375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Test loss: 1.0021851062774658 / Test accuracy: 0.7556000351905823 / Test Roc : 0.8104640676217574

# %% [markdown]
# With the addition of batch normalization we can see significant improvment in model

# %% [markdown]
# ### Model 2

# %% [markdown]
# changing stride from 1 to 2

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 100
stride = 2


early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))


model.add(Conv2D(second_filters, kernel_size))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))

model.add(Conv2D(third_filters, kernel_size))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
#   1/200 [..............................] - ETA: 3:19 - loss: 0.8003 - accuracy: 0.5200
# 2022-05-25 13:39:26.221393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 199/200 [============================>.] - ETA: 0s - loss: 0.4716 - accuracy: 0.7964
# 2022-05-25 13:39:33.287449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.88232, saving model to weights.hdf5
# 200/200 [==============================] - 8s 37ms/step - loss: 0.4711 - accuracy: 0.7966 - val_loss: 1.8823 - val_accuracy: 0.6040
# Epoch 2/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3850 - accuracy: 0.8318
# Epoch 2: val_loss improved from 1.88232 to 0.67642, saving model to weights.hdf5
# 200/200 [==============================] - 7s 36ms/step - loss: 0.3848 - accuracy: 0.8321 - val_loss: 0.6764 - val_accuracy: 0.6568
# Epoch 3/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3614 - accuracy: 0.8438
# Epoch 3: val_loss improved from 0.67642 to 0.46032, saving model to weights.hdf5
# 200/200 [==============================] - 7s 36ms/step - loss: 0.3613 - accuracy: 0.8439 - val_loss: 0.4603 - val_accuracy: 0.7952
# Epoch 4/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3488 - accuracy: 0.8516
# Epoch 4: val_loss did not improve from 0.46032
# 200/200 [==============================] - 7s 36ms/step - loss: 0.3485 - accuracy: 0.8520 - val_loss: 0.5420 - val_accuracy: 0.7200
# Epoch 5/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3263 - accuracy: 0.8594
# Epoch 5: val_loss did not improve from 0.46032
# 200/200 [==============================] - 7s 36ms/step - loss: 0.3262 - accuracy: 0.8595 - val_loss: 0.6360 - val_accuracy: 0.7556
# Epoch 6/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3130 - accuracy: 0.8695
# Epoch 6: val_loss did not improve from 0.46032
# 200/200 [==============================] - 7s 36ms/step - loss: 0.3131 - accuracy: 0.8694 - val_loss: 0.4992 - val_accuracy: 0.7952
# Epoch 7/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2866 - accuracy: 0.8786
# Epoch 7: val_loss did not improve from 0.46032
# 200/200 [==============================] - 7s 36ms/step - loss: 0.2868 - accuracy: 0.8785 - val_loss: 0.6162 - val_accuracy: 0.7916
# Epoch 8/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2649 - accuracy: 0.8891
# Epoch 8: val_loss improved from 0.46032 to 0.41017, saving model to weights.hdf5
# 200/200 [==============================] - 7s 36ms/step - loss: 0.2654 - accuracy: 0.8888 - val_loss: 0.4102 - val_accuracy: 0.8348
# Epoch 9/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2330 - accuracy: 0.9057
# Epoch 9: val_loss did not improve from 0.41017
# 200/200 [==============================] - 7s 36ms/step - loss: 0.2332 - accuracy: 0.9055 - val_loss: 0.4361 - val_accuracy: 0.8200
# Epoch 10/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.1955 - accuracy: 0.9222
# Epoch 10: val_loss did not improve from 0.41017
# 200/200 [==============================] - 7s 36ms/step - loss: 0.1958 - accuracy: 0.9222 - val_loss: 0.5065 - val_accuracy: 0.7892
# Epoch 11/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9372
# Epoch 11: val_loss did not improve from 0.41017
# 200/200 [==============================] - 7s 36ms/step - loss: 0.1593 - accuracy: 0.9372 - val_loss: 0.8050 - val_accuracy: 0.7552
# Epoch 12/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9545
# Epoch 12: val_loss did not improve from 0.41017
# 200/200 [==============================] - 7s 36ms/step - loss: 0.1237 - accuracy: 0.9544 - val_loss: 0.8644 - val_accuracy: 0.7504
# Epoch 13/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.0974 - accuracy: 0.9630
# Epoch 13: val_loss did not improve from 0.41017
# 200/200 [==============================] - 7s 36ms/step - loss: 0.0973 - accuracy: 0.9630 - val_loss: 0.9602 - val_accuracy: 0.7372

# %%
visual_results(base_model,test_x,test_y)
# Out:
# 15/79 [====>.........................] - ETA: 0s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 13:40:59.895762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 9ms/step
# 2022-05-25 13:41:00.813135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Test loss: 0.8593667149543762 / Test accuracy: 0.7540000081062317 / Test Roc : 0.8468500307825423

# %% [markdown]
# with the addition of stride we can see slight improvement in roc

# %% [markdown]
# ### Model 3

# %% [markdown]
# adding dropout

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 100
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
# 2022-05-25 15:27:16.794685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 200/200 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.8084
# 2022-05-25 15:27:28.170196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.37390, saving model to weights.hdf5
# 200/200 [==============================] - 12s 57ms/step - loss: 0.4245 - accuracy: 0.8084 - val_loss: 1.3739 - val_accuracy: 0.6028
# Epoch 2/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8356
# Epoch 2: val_loss improved from 1.37390 to 0.58869, saving model to weights.hdf5
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3745 - accuracy: 0.8359 - val_loss: 0.5887 - val_accuracy: 0.7516
# Epoch 3/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3487 - accuracy: 0.8461
# Epoch 3: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3489 - accuracy: 0.8460 - val_loss: 0.8479 - val_accuracy: 0.7052
# Epoch 4/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.8578
# Epoch 4: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 52ms/step - loss: 0.3305 - accuracy: 0.8579 - val_loss: 0.7055 - val_accuracy: 0.7380
# Epoch 5/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3128 - accuracy: 0.8671
# Epoch 5: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3133 - accuracy: 0.8668 - val_loss: 1.0071 - val_accuracy: 0.6332
# Epoch 6/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8751
# Epoch 6: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2988 - accuracy: 0.8751 - val_loss: 0.6920 - val_accuracy: 0.7416
# Epoch 7/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.8808
# Epoch 7: val_loss improved from 0.58869 to 0.38490, saving model to weights.hdf5
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2787 - accuracy: 0.8809 - val_loss: 0.3849 - val_accuracy: 0.8480
# Epoch 8/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.8896
# Epoch 8: val_loss did not improve from 0.38490
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2696 - accuracy: 0.8896 - val_loss: 0.7308 - val_accuracy: 0.7464
# Epoch 9/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2423 - accuracy: 0.9005
# Epoch 9: val_loss did not improve from 0.38490
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2425 - accuracy: 0.9003 - val_loss: 0.7578 - val_accuracy: 0.7096
# Epoch 10/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9079
# Epoch 10: val_loss did not improve from 0.38490
# 200/200 [==============================] - 11s 53ms/step - loss: 0.2237 - accuracy: 0.9079 - val_loss: 0.6847 - val_accuracy: 0.7852
# Epoch 11/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9168
# Epoch 11: val_loss did not improve from 0.38490
# 200/200 [==============================] - 11s 54ms/step - loss: 0.2054 - accuracy: 0.9168 - val_loss: 0.6132 - val_accuracy: 0.7644
# Epoch 12/15
# 200/200 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9236
# Epoch 12: val_loss did not improve from 0.38490
# 200/200 [==============================] - 11s 54ms/step - loss: 0.1902 - accuracy: 0.9236 - val_loss: 0.4823 - val_accuracy: 0.8152

# %%
visual_results(base_model,test_x,test_y)
# Out:
#  1/79 [..............................] - ETA: 13s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 15:29:43.287186: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 9ms/step
# 2022-05-25 15:29:44.333613: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Test loss: 0.458243727684021 / Test accuracy: 0.8252000212669373 / Test Roc : 0.898266526897286

# %% [markdown]
# ### Model 4

# %% [markdown]
# changing maxpool to averagepool

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 100
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(AveragePooling2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(AveragePooling2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(AveragePooling2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
# 2022-05-25 15:24:22.453404: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 199/200 [============================>.] - ETA: 0s - loss: 0.4284 - accuracy: 0.8100
# 2022-05-25 15:24:31.917367: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 2.21477, saving model to weights.hdf5
# 200/200 [==============================] - 12s 48ms/step - loss: 0.4283 - accuracy: 0.8099 - val_loss: 2.2148 - val_accuracy: 0.5464
# Epoch 2/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3823 - accuracy: 0.8337
# Epoch 2: val_loss improved from 2.21477 to 0.41542, saving model to weights.hdf5
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3818 - accuracy: 0.8338 - val_loss: 0.4154 - val_accuracy: 0.8228
# Epoch 3/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8437
# Epoch 3: val_loss did not improve from 0.41542
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3614 - accuracy: 0.8437 - val_loss: 0.6705 - val_accuracy: 0.7204
# Epoch 4/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3470 - accuracy: 0.8489
# Epoch 4: val_loss did not improve from 0.41542
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3472 - accuracy: 0.8488 - val_loss: 0.7061 - val_accuracy: 0.6780
# Epoch 5/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3325 - accuracy: 0.8572
# Epoch 5: val_loss did not improve from 0.41542
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3325 - accuracy: 0.8572 - val_loss: 1.2966 - val_accuracy: 0.6128
# Epoch 6/15
# 200/200 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8623
# Epoch 6: val_loss did not improve from 0.41542
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3198 - accuracy: 0.8623 - val_loss: 0.6483 - val_accuracy: 0.7268
# Epoch 7/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.8733
# Epoch 7: val_loss did not improve from 0.41542
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3010 - accuracy: 0.8734 - val_loss: 0.4904 - val_accuracy: 0.7636

# %%
visual_results(base_model,test_x,test_y)
# Out:
#  8/79 [==>...........................] - ETA: 0s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 15:25:28.768337: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 10ms/step
# 2022-05-25 15:25:29.679533: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Test loss: 0.46025681495666504 / Test accuracy: 0.7884000539779663 / Test Roc : 0.8553100717150036

# %% [markdown]
# In maxpool acuracy was better compare to average pool.

# %% [markdown]
# ## Final Model architecture

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 100
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
# 2022-05-25 15:27:16.794685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 200/200 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.8084
# 2022-05-25 15:27:28.170196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.37390, saving model to weights.hdf5
# 200/200 [==============================] - 12s 57ms/step - loss: 0.4245 - accuracy: 0.8084 - val_loss: 1.3739 - val_accuracy: 0.6028
# Epoch 2/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8356
# Epoch 2: val_loss improved from 1.37390 to 0.58869, saving model to weights.hdf5
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3745 - accuracy: 0.8359 - val_loss: 0.5887 - val_accuracy: 0.7516
# Epoch 3/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3487 - accuracy: 0.8461
# Epoch 3: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3489 - accuracy: 0.8460 - val_loss: 0.8479 - val_accuracy: 0.7052
# Epoch 4/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.8578
# Epoch 4: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 52ms/step - loss: 0.3305 - accuracy: 0.8579 - val_loss: 0.7055 - val_accuracy: 0.7380
# Epoch 5/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.3128 - accuracy: 0.8671
# Epoch 5: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3133 - accuracy: 0.8668 - val_loss: 1.0071 - val_accuracy: 0.6332
# Epoch 6/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8751
# Epoch 6: val_loss did not improve from 0.58869
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2988 - accuracy: 0.8751 - val_loss: 0.6920 - val_accuracy: 0.7416
# Epoch 7/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.8808
# Epoch 7: val_loss improved from 0.58869 to 0.38490, saving model to weights.hdf5
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2787 - accuracy: 0.8809 - val_loss: 0.3849 - val_accuracy: 0.8480
# Epoch 8/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.8896
# Epoch 8: val_loss did not improve from 0.38490
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2696 - accuracy: 0.8896 - val_loss: 0.7308 - val_accuracy: 0.7464
# Epoch 9/15
# 199/200 [============================>.] - ETA: 0s - loss: 0.2423 - accuracy: 0.9005
# Epoch 9: val_loss did not improve from 0.38490
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2425 - accuracy: 0.9003 - val_loss: 0.7578 - val_accuracy: 0.7096
# Epoch 10/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9079
# Epoch 10: val_loss did not improve from 0.38490
# 200/200 [==============================] - 11s 53ms/step - loss: 0.2237 - accuracy: 0.9079 - val_loss: 0.6847 - val_accuracy: 0.7852
# Epoch 11/15
# 200/200 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9168
# Epoch 11: val_loss did not improve from 0.38490
# 200/200 [==============================] - 11s 54ms/step - loss: 0.2054 - accuracy: 0.9168 - val_loss: 0.6132 - val_accuracy: 0.7644
# Epoch 12/15
# 200/200 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9236
# Epoch 12: val_loss did not improve from 0.38490
# 200/200 [==============================] - 11s 54ms/step - loss: 0.1902 - accuracy: 0.9236 - val_loss: 0.4823 - val_accuracy: 0.8152

# %%
visual_results(base_model,test_x,test_y)
# Out:
#  8/79 [==>...........................] - ETA: 1s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 79/79 [==============================] - 1s 11ms/step
# Test loss: 0.458243727684021 / Test accuracy: 0.8252000212669373 / Test Roc : 0.898266526897286

# %% [markdown]
# # Step 4 - Hyper parameter tuning

# %% [markdown]
# ## changing batch size from 100 to 50

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 50
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])
# Out:
# Epoch 1/15
# 2022-05-25 15:57:31.264414: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 399/400 [============================>.] - ETA: 0s - loss: 0.1223 - accuracy: 0.9531
# 2022-05-25 15:57:42.762314: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.51193, saving model to weights.hdf5
# 400/400 [==============================] - 12s 29ms/step - loss: 0.1223 - accuracy: 0.9531 - val_loss: 0.5119 - val_accuracy: 0.8356
# Epoch 2/15
# 399/400 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9630
# Epoch 2: val_loss did not improve from 0.51193
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0978 - accuracy: 0.9630 - val_loss: 0.7334 - val_accuracy: 0.8036
# Epoch 3/15
# 400/400 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9642
# Epoch 3: val_loss did not improve from 0.51193
# 400/400 [==============================] - 11s 27ms/step - loss: 0.0938 - accuracy: 0.9642 - val_loss: 0.7641 - val_accuracy: 0.7892
# Epoch 4/15
# 399/400 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9660
# Epoch 4: val_loss did not improve from 0.51193
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0870 - accuracy: 0.9659 - val_loss: 0.9785 - val_accuracy: 0.7756
# Epoch 5/15
# 399/400 [============================>.] - ETA: 0s - loss: 0.0861 - accuracy: 0.9676
# Epoch 5: val_loss did not improve from 0.51193
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0860 - accuracy: 0.9676 - val_loss: 0.9305 - val_accuracy: 0.8012
# Epoch 6/15
# 399/400 [============================>.] - ETA: 0s - loss: 0.0786 - accuracy: 0.9707
# Epoch 6: val_loss did not improve from 0.51193
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0785 - accuracy: 0.9708 - val_loss: 2.7656 - val_accuracy: 0.7180

# %%
visual_results(base_model,test_x,test_y)
# Out:
#  4/79 [>.............................] - ETA: 1s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 15:58:40.426860: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 11ms/step
# 2022-05-25 15:58:41.446486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Test loss: 2.6867775917053223 / Test accuracy: 0.7168000340461731 / Test Roc : 0.732878750062397

# %% [markdown]
# reducing batch size has not much improvemento ver model

# %% [markdown]
# ## Increasing batch size

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

kernel_size = (3,3)
pool_size= (2,2)
first_filters c= 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.Adam()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 120
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])

visual_results(base_model,test_x,test_y)
# Out:
# Epoch 1/15
# 2022-05-25 15:59:52.661198: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9770
# 2022-05-25 16:00:07.190270: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.81345, saving model to weights.hdf5
# 167/167 [==============================] - 16s 78ms/step - loss: 0.0661 - accuracy: 0.9770 - val_loss: 0.8135 - val_accuracy: 0.8052
# Epoch 2/15
# 167/167 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9828
# Epoch 2: val_loss improved from 0.81345 to 0.59472, saving model to weights.hdf5
# 167/167 [==============================] - 10s 62ms/step - loss: 0.0484 - accuracy: 0.9828 - val_loss: 0.5947 - val_accuracy: 0.8488
# Epoch 3/15
# 166/167 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9842
# Epoch 3: val_loss did not improve from 0.59472
# 167/167 [==============================] - 10s 62ms/step - loss: 0.0455 - accuracy: 0.9843 - val_loss: 0.7852 - val_accuracy: 0.8200
# Epoch 4/15
# 166/167 [============================>.] - ETA: 0s - loss: 0.0401 - accuracy: 0.9860
# Epoch 4: val_loss did not improve from 0.59472
# 167/167 [==============================] - 10s 62ms/step - loss: 0.0400 - accuracy: 0.9860 - val_loss: 0.6197 - val_accuracy: 0.8256
# Epoch 5/15
# 166/167 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9869
# Epoch 5: val_loss did not improve from 0.59472
# 167/167 [==============================] - 11s 63ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.8760 - val_accuracy: 0.8216
# Epoch 6/15
# 166/167 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9855
# Epoch 6: val_loss did not improve from 0.59472
# 167/167 [==============================] - 10s 62ms/step - loss: 0.0413 - accuracy: 0.9856 - val_loss: 1.3856 - val_accuracy: 0.7868
# Epoch 7/15
# 166/167 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9881
# Epoch 7: val_loss did not improve from 0.59472
# 167/167 [==============================] - 11s 63ms/step - loss: 0.0333 - accuracy: 0.9881 - val_loss: 0.7371 - val_accuracy: 0.8336
#  1/79 [..............................] - ETA: 9s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 16:01:10.453192: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 10ms/step
# Test loss: 0.7020627856254578 / Test accuracy: 0.8584000468254089 / Test Roc : 0.9184389091332633

# %% [markdown]
# Changing optimizer to sgd

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.SGD()
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 120
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])

visual_results(base_model,test_x,test_y)
# Out:
# Epoch 1/15
# 2022-05-25 16:05:07.166549: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.4927 - accuracy: 0.7640
# 2022-05-25 16:05:19.514153: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.15002, saving model to weights.hdf5
# 167/167 [==============================] - 13s 74ms/step - loss: 0.4927 - accuracy: 0.7640 - val_loss: 1.1500 - val_accuracy: 0.6040
# Epoch 2/15
# 167/167 [==============================] - ETA: 0s - loss: 0.4314 - accuracy: 0.8061
# Epoch 2: val_loss improved from 1.15002 to 0.68769, saving model to weights.hdf5
# 167/167 [==============================] - 12s 73ms/step - loss: 0.4314 - accuracy: 0.8061 - val_loss: 0.6877 - val_accuracy: 0.6788
# Epoch 3/15
# 167/167 [==============================] - ETA: 0s - loss: 0.4143 - accuracy: 0.8167
# Epoch 3: val_loss improved from 0.68769 to 0.50562, saving model to weights.hdf5
# 167/167 [==============================] - 12s 72ms/step - loss: 0.4143 - accuracy: 0.8167 - val_loss: 0.5056 - val_accuracy: 0.7512
# Epoch 4/15
# 167/167 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.8225
# Epoch 4: val_loss did not improve from 0.50562
# 167/167 [==============================] - 12s 72ms/step - loss: 0.4023 - accuracy: 0.8225 - val_loss: 0.5357 - val_accuracy: 0.7336
# Epoch 5/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3953 - accuracy: 0.8241
# Epoch 5: val_loss improved from 0.50562 to 0.47543, saving model to weights.hdf5
# 167/167 [==============================] - 12s 72ms/step - loss: 0.3953 - accuracy: 0.8241 - val_loss: 0.4754 - val_accuracy: 0.7836
# Epoch 6/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8293
# Epoch 6: val_loss did not improve from 0.47543
# 167/167 [==============================] - 12s 72ms/step - loss: 0.3892 - accuracy: 0.8293 - val_loss: 0.5044 - val_accuracy: 0.7752
# Epoch 7/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3813 - accuracy: 0.8325
# Epoch 7: val_loss did not improve from 0.47543
# 167/167 [==============================] - 13s 76ms/step - loss: 0.3813 - accuracy: 0.8325 - val_loss: 0.6139 - val_accuracy: 0.7556
# Epoch 8/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8361
# Epoch 8: val_loss improved from 0.47543 to 0.42552, saving model to weights.hdf5
# 167/167 [==============================] - 12s 73ms/step - loss: 0.3756 - accuracy: 0.8361 - val_loss: 0.4255 - val_accuracy: 0.8152
# Epoch 9/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3685 - accuracy: 0.8374
# Epoch 9: val_loss did not improve from 0.42552
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3685 - accuracy: 0.8374 - val_loss: 0.6107 - val_accuracy: 0.7632
# Epoch 10/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.8417
# Epoch 10: val_loss improved from 0.42552 to 0.41458, saving model to weights.hdf5
# 167/167 [==============================] - 12s 73ms/step - loss: 0.3634 - accuracy: 0.8417 - val_loss: 0.4146 - val_accuracy: 0.8120
# Epoch 11/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.8412
# Epoch 11: val_loss did not improve from 0.41458
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3618 - accuracy: 0.8412 - val_loss: 0.4176 - val_accuracy: 0.8228
# Epoch 12/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.8420
# Epoch 12: val_loss did not improve from 0.41458
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3570 - accuracy: 0.8420 - val_loss: 0.5216 - val_accuracy: 0.7728
# Epoch 13/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8467
# Epoch 13: val_loss did not improve from 0.41458
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3518 - accuracy: 0.8467 - val_loss: 0.4380 - val_accuracy: 0.8096
# Epoch 14/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8478
# Epoch 14: val_loss did not improve from 0.41458
# 167/167 [==============================] - 14s 82ms/step - loss: 0.3481 - accuracy: 0.8478 - val_loss: 0.6251 - val_accuracy: 0.7644
# Epoch 15/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3457 - accuracy: 0.8493
# Epoch 15: val_loss did not improve from 0.41458
# 167/167 [==============================] - 13s 76ms/step - loss: 0.3457 - accuracy: 0.8493 - val_loss: 0.4882 - val_accuracy: 0.7848
#  1/79 [..............................] - ETA: 12s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 16:08:13.614484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 12ms/step
# Test loss: 0.46785277128219604 / Test accuracy: 0.796000063419342 / Test Roc : 0.8909226443035657

# %% [markdown]
# ## Learning rate scheduling

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.SGD(learning_rate=lr_schedule)
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 120
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])

visual_results(base_model,test_x,test_y)
# Out:
# Epoch 1/15
# 2022-05-25 16:09:34.799420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.4951 - accuracy: 0.7659
# 2022-05-25 16:09:47.075124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.12458, saving model to weights.hdf5
# 167/167 [==============================] - 13s 74ms/step - loss: 0.4951 - accuracy: 0.7659 - val_loss: 1.1246 - val_accuracy: 0.6040
# Epoch 2/15
# 167/167 [==============================] - ETA: 0s - loss: 0.4359 - accuracy: 0.8044
# Epoch 2: val_loss improved from 1.12458 to 0.56330, saving model to weights.hdf5
# 167/167 [==============================] - 12s 72ms/step - loss: 0.4359 - accuracy: 0.8044 - val_loss: 0.5633 - val_accuracy: 0.7080
# Epoch 3/15
# 167/167 [==============================] - ETA: 0s - loss: 0.4139 - accuracy: 0.8144
# Epoch 3: val_loss improved from 0.56330 to 0.49767, saving model to weights.hdf5
# 167/167 [==============================] - 12s 72ms/step - loss: 0.4139 - accuracy: 0.8144 - val_loss: 0.4977 - val_accuracy: 0.7668
# Epoch 4/15
# 167/167 [==============================] - ETA: 0s - loss: 0.4037 - accuracy: 0.8215
# Epoch 4: val_loss did not improve from 0.49767
# 167/167 [==============================] - 12s 75ms/step - loss: 0.4037 - accuracy: 0.8215 - val_loss: 0.7824 - val_accuracy: 0.7020
# Epoch 5/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8268
# Epoch 5: val_loss improved from 0.49767 to 0.45558, saving model to weights.hdf5
# 167/167 [==============================] - 12s 73ms/step - loss: 0.3942 - accuracy: 0.8268 - val_loss: 0.4556 - val_accuracy: 0.7884
# Epoch 6/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8308
# Epoch 6: val_loss did not improve from 0.45558
# 167/167 [==============================] - 12s 73ms/step - loss: 0.3848 - accuracy: 0.8308 - val_loss: 0.5223 - val_accuracy: 0.7688
# Epoch 7/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3822 - accuracy: 0.8306
# Epoch 7: val_loss did not improve from 0.45558
# 167/167 [==============================] - 12s 73ms/step - loss: 0.3822 - accuracy: 0.8306 - val_loss: 0.5564 - val_accuracy: 0.7652
# Epoch 8/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3749 - accuracy: 0.8356
# Epoch 8: val_loss improved from 0.45558 to 0.41837, saving model to weights.hdf5
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3749 - accuracy: 0.8356 - val_loss: 0.4184 - val_accuracy: 0.8084
# Epoch 9/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8383
# Epoch 9: val_loss did not improve from 0.41837
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3696 - accuracy: 0.8383 - val_loss: 0.4492 - val_accuracy: 0.7908
# Epoch 10/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3632 - accuracy: 0.8416
# Epoch 10: val_loss did not improve from 0.41837
# 167/167 [==============================] - 12s 73ms/step - loss: 0.3632 - accuracy: 0.8416 - val_loss: 0.4288 - val_accuracy: 0.8136
# Epoch 11/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.8418
# Epoch 11: val_loss did not improve from 0.41837
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3610 - accuracy: 0.8418 - val_loss: 0.7937 - val_accuracy: 0.7128
# Epoch 12/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8463
# Epoch 12: val_loss did not improve from 0.41837
# 167/167 [==============================] - 13s 75ms/step - loss: 0.3528 - accuracy: 0.8463 - val_loss: 0.6749 - val_accuracy: 0.7448
# Epoch 13/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8469
# Epoch 13: val_loss did not improve from 0.41837
# 167/167 [==============================] - 13s 75ms/step - loss: 0.3488 - accuracy: 0.8469 - val_loss: 0.4307 - val_accuracy: 0.8048
#  1/79 [..............................] - ETA: 12s
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 16:12:15.562957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 12ms/step
# Test loss: 0.41086965799331665 / Test accuracy: 0.8128000497817993 / Test Roc : 0.8981067904624037

# %% [markdown]
# ## Adding momentum to sgd

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.SGD(learning_rate=lr_schedule,momentum=0.8)
loss_function = "binary_crossentropy"
no_epochs = 15
batch_size = 120
stride = 2

dense_dropout = 0.1
conv_dropout = 0.1


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])

visual_results(base_model,test_x,test_y)
# Out:
# Epoch 1/15
# 2022-05-25 17:34:54.522701: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.4501 - accuracy: 0.7956
# 2022-05-25 17:35:05.546747: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.48823, saving model to weights.hdf5
# 167/167 [==============================] - 12s 67ms/step - loss: 0.4501 - accuracy: 0.7956 - val_loss: 1.4882 - val_accuracy: 0.6040
# Epoch 2/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3948 - accuracy: 0.8252
# Epoch 2: val_loss improved from 1.48823 to 0.48428, saving model to weights.hdf5
# 167/167 [==============================] - 11s 64ms/step - loss: 0.3948 - accuracy: 0.8252 - val_loss: 0.4843 - val_accuracy: 0.7696
# Epoch 3/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8351
# Epoch 3: val_loss improved from 0.48428 to 0.42160, saving model to weights.hdf5
# 167/167 [==============================] - 11s 64ms/step - loss: 0.3728 - accuracy: 0.8351 - val_loss: 0.4216 - val_accuracy: 0.8128
# Epoch 4/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.8425
# Epoch 4: val_loss did not improve from 0.42160
# 167/167 [==============================] - 11s 69ms/step - loss: 0.3622 - accuracy: 0.8425 - val_loss: 0.6186 - val_accuracy: 0.7348
# Epoch 5/15
# 166/167 [============================>.] - ETA: 0s - loss: 0.3457 - accuracy: 0.8496
# Epoch 5: val_loss did not improve from 0.42160
# 167/167 [==============================] - 10s 62ms/step - loss: 0.3455 - accuracy: 0.8498 - val_loss: 0.5071 - val_accuracy: 0.7968
# Epoch 6/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8559
# Epoch 6: val_loss did not improve from 0.42160
# 167/167 [==============================] - 10s 62ms/step - loss: 0.3367 - accuracy: 0.8559 - val_loss: 0.9043 - val_accuracy: 0.7000
# Epoch 7/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8566
# Epoch 7: val_loss did not improve from 0.42160
# 167/167 [==============================] - 11s 64ms/step - loss: 0.3295 - accuracy: 0.8566 - val_loss: 0.6559 - val_accuracy: 0.7508
# Epoch 8/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.8617
# Epoch 8: val_loss improved from 0.42160 to 0.40416, saving model to weights.hdf5
# 167/167 [==============================] - 12s 72ms/step - loss: 0.3195 - accuracy: 0.8617 - val_loss: 0.4042 - val_accuracy: 0.8216
# Epoch 9/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8641
# Epoch 9: val_loss did not improve from 0.40416
# 167/167 [==============================] - 11s 68ms/step - loss: 0.3136 - accuracy: 0.8641 - val_loss: 0.4192 - val_accuracy: 0.8220
# Epoch 10/15
# 167/167 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.8705
# Epoch 10: val_loss did not improve from 0.40416
# 167/167 [==============================] - 12s 74ms/step - loss: 0.3027 - accuracy: 0.8705 - val_loss: 0.7716 - val_accuracy: 0.7576
# Epoch 11/15
# 167/167 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.8710
# Epoch 11: val_loss did not improve from 0.40416
# 167/167 [==============================] - 12s 74ms/step - loss: 0.2970 - accuracy: 0.8710 - val_loss: 0.5205 - val_accuracy: 0.7812
# Epoch 12/15
# 167/167 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8768
# Epoch 12: val_loss did not improve from 0.40416
# 167/167 [==============================] - 12s 72ms/step - loss: 0.2946 - accuracy: 0.8768 - val_loss: 1.3401 - val_accuracy: 0.6612
# Epoch 13/15
# 167/167 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8801
# Epoch 13: val_loss improved from 0.40416 to 0.39340, saving model to weights.hdf5
# 167/167 [==============================] - 12s 74ms/step - loss: 0.2844 - accuracy: 0.8801 - val_loss: 0.3934 - val_accuracy: 0.8336
# Epoch 14/15
# 167/167 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8851
# Epoch 14: val_loss did not improve from 0.39340
# 167/167 [==============================] - 12s 73ms/step - loss: 0.2792 - accuracy: 0.8851 - val_loss: 0.8334 - val_accuracy: 0.7172
# Epoch 15/15
# 167/167 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.8903
# Epoch 15: val_loss improved from 0.39340 to 0.37398, saving model to weights.hdf5
# 167/167 [==============================] - 12s 69ms/step - loss: 0.2669 - accuracy: 0.8903 - val_loss: 0.3740 - val_accuracy: 0.8440
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 17:37:47.224452: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 11ms/step
# Test loss: 0.3382577896118164 / Test accuracy: 0.8560000658035278 / Test Roc : 0.9293425847351869

# %% [markdown]
# ## Increase Epoch

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                               verbose=1, save_best_only=True)

kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128
optimizer = keras.optimizers.SGD(learning_rate=lr_schedule)
loss_function = "binary_crossentropy"
no_epochs = 25
batch_size = 120
stride = 1

dense_dropout = 0.1
conv_dropout = 0.1


#create model
model = Sequential()
model.add(Conv2D(first_filters, kernel_size, input_shape=(96, 96, 3),strides = stride))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Conv2D(first_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))


model.add(Conv2D(second_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Dropout(conv_dropout))

model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPool2D(pool_size))
model.add(Conv2D(third_filters, kernel_size, use_bias = False))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(conv_dropout))

model.add(Flatten())
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(dense_dropout))

###final output layer
model.add(Dense(1,activation='sigmoid'))

# Compile the model
model.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])


# Fit data to model
base_model = model.fit(train_x, train_y,
                    validation_data=(val_x, val_y),
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose = 1,
                    callbacks = [early_stopping, checkpointer])

visual_results(base_model,test_x,test_y)
# Out:
# Epoch 1/25
# 2022-05-25 16:31:05.106876: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 167/167 [==============================] - ETA: 0s - loss: 0.4632 - accuracy: 0.7865
# 2022-05-25 16:31:46.971532: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 1.08405, saving model to weights.hdf5
# 167/167 [==============================] - 44s 251ms/step - loss: 0.4632 - accuracy: 0.7865 - val_loss: 1.0840 - val_accuracy: 0.6040
# Epoch 2/25
# 167/167 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8212
# Epoch 2: val_loss improved from 1.08405 to 0.41801, saving model to weights.hdf5
# 167/167 [==============================] - 40s 240ms/step - loss: 0.4082 - accuracy: 0.8212 - val_loss: 0.4180 - val_accuracy: 0.8180
# Epoch 3/25
# 167/167 [==============================] - ETA: 0s - loss: 0.3872 - accuracy: 0.8299
# Epoch 3: val_loss did not improve from 0.41801
# 167/167 [==============================] - 40s 241ms/step - loss: 0.3872 - accuracy: 0.8299 - val_loss: 0.4883 - val_accuracy: 0.7780
# Epoch 4/25
# 167/167 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.8359
# Epoch 4: val_loss did not improve from 0.41801
# 167/167 [==============================] - 40s 240ms/step - loss: 0.3737 - accuracy: 0.8359 - val_loss: 0.4699 - val_accuracy: 0.7840
# Epoch 5/25
# 167/167 [==============================] - ETA: 0s - loss: 0.3619 - accuracy: 0.8437
# Epoch 5: val_loss did not improve from 0.41801
# 167/167 [==============================] - 40s 241ms/step - loss: 0.3619 - accuracy: 0.8437 - val_loss: 0.4822 - val_accuracy: 0.7840
# Epoch 6/25
# 167/167 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.8456
# Epoch 6: val_loss did not improve from 0.41801
# 167/167 [==============================] - 42s 250ms/step - loss: 0.3540 - accuracy: 0.8456 - val_loss: 0.4836 - val_accuracy: 0.7912
# Epoch 7/25
# 167/167 [==============================] - ETA: 0s - loss: 0.3457 - accuracy: 0.8494
# Epoch 7: val_loss did not improve from 0.41801
# 167/167 [==============================] - 42s 251ms/step - loss: 0.3457 - accuracy: 0.8494 - val_loss: 0.5192 - val_accuracy: 0.7876
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/3385275531.py:17: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(test_df_x, verbose=1)
# 2022-05-25 16:35:53.620702: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 2s 20ms/step
# Test loss: 0.46595606207847595 / Test accuracy: 0.8092000484466553 / Test Roc : 0.9015893775270803

# %% [markdown]
# # Step 5 - Conclusion

# %%
from IPython.display import Image

# %% [markdown]
# Below is summary for all the models tried with different architect and hyperparameter tunning

# %% [markdown]
# ![model_summary.png](attachment:model_summary.png)

# %% [markdown]
# Best model we got is after adding momentum to sgd

# %% [markdown]
# # Final submission

# %%
# Generate generalization metrics
score = model.evaluate(test_x, test_y, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Test loss: 0.3382577896118164 / Test accuracy: 0.8560000658035278

# %%
test_df1 = pd.DataFrame(os.listdir(basedir + 'test/'))

# %%
test_df1 = test_df1.iloc[:,0].str.split('.',expand = True)
test_df1.drop(1,axis = 1,inplace = True)
test_df1.rename(columns = {0:'id'},inplace = True)

# %%
test_df1['label'] = 0

# %%
N=test_df1.shape[0]
final_test_x,final_test_y = load_data(basedir + 'test/',N=N,df=test_df1)
# Out:
#   0%|          | 0/57458 [00:00<?, ?it/s]

# %%
y_pred_keras = model.predict_generator(final_test_x, verbose=1)
# Out:
# /var/folders/xf/6fdb6j7912v8q7z1m24hkzlw0000gn/T/ipykernel_813/557378195.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred_keras = model.predict_generator(final_test_x, verbose=1)
# 1796/1796 [==============================] - 18s 10ms/step

# %%
predictions = np.array(y_pred_keras)
test_df1['label'] = predictions
submission = test_df1[["id", "label"]]
submission.head()
# Out:
#                                          id     label
# 0  fd0a060ef9c30c9a83f6b4bfb568db74b099154d  0.699932
# 1  1f9ee06f06d329eb7902a2e03ab3835dd0484581  0.099044
# 2  19709bec800f372d0b1d085da6933dd3ef108846  0.537550
# 3  7a34fc34523063f13f0617f7518a0330f6187bd3  0.489825
# 4  93be720ca2b95fe2126cf2e1ed752bd759e9b0ed  0.002550

# %%
#submission
submission.to_csv('/Users/vishalverma/Vishal/Github_project/Cancer-Detection/Results/cnn_model.csv', index = False, header = True)
