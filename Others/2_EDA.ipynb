# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kaggle
import json
import zipfile
import os

# %%
sample_sub = pd.read_csv('/Users/vishalverma/Vishal/Kaggle/Cancer detection/Data/histopathologic-cancer-detection/sample_submission.csv')
train_df1 = pd.read_csv('/Users/vishalverma/Vishal/Kaggle/Cancer detection/Data/histopathologic-cancer-detection/train_labels.csv')

# %%
val1 = train_df1.label.value_counts(normalize=True).values
lables = train_df1.label.value_counts(normalize=True).index

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(val1, labels=labels1, autopct='%.1f%%')
ax.set_title('Target distribution')
plt.tight_layout()

# %%
plt.pie(val1)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb02fef9750>,
# ...
#  [Text(1.1, 0.0, ''), Text(-1.1, 1.3471114790620887e-16, '')])

# %%
val1
# Out:
# Int64Index([0, 1], dtype='int64')
